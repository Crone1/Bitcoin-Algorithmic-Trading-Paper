# %% [markdown]
# # Setup

# %% [markdown]
# ### Import relevant features

# %%
# general packages
import os
import pandas as pd
from tqdm.auto import tqdm
import numpy as np

# %%
# packages for the YAMl file
import yaml

# %%
# packages for feature importance
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %% [markdown]
# ### Set the maximum output number of columns and rows

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Read in the variables from the YAML file

# %%
# read in YAML configuration file
with open("../../Config_files/config.yaml", "r") as variables:
    config_variables = yaml.load(variables, Loader=yaml.FullLoader)

# %%
data_directory = config_variables["data_directory"]

# %%
train_intervals_list = config_variables["train_intervals_list"]

# %%
shift_periods_in_days_list = config_variables["shift_periods_in_days_list"]

# %%
random_seed = config_variables["random_seed"]

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Read in the processed data

# %%
processed_data = pd.read_csv(os.path.join(data_directory, 'processed_data.csv'))

# %%
processed_data.shape
# Out:
# (4510, 1464)

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Assertain the most important features in our data

# %%
def get_cols_with_nan(df):

    nan_cols = []
    for col in df.columns:
        any_nan = df[col].isnull().values.any()
        if any_nan:
            nan_cols.append(col)

    return nan_cols


def drop_nan_cols(df):

    nan_cols = get_cols_with_nan(df)

    dropped = df.copy()
    print("Dropping the following 'Nan' columns:\n", nan_cols)
    return dropped.drop(columns=nan_cols)

# %%
def get_subset_of_data(df, start_date, end_date):
    
    """
    Take in a dataframe with a date column and output the subset of this dataframe using the specified date range of the input dataframe

    Parameters:
        df (dataframe) : A pandas dataframe that has a columns called "date"
        start_date (string) : A String of the minimum date we want in the subset dataframe
        end_date (string) : A String of the maximum date we want in the subset dataframe

    Returns:
        (dataframe) : A pandas dataframe which is a subset of the original dataframe whose data only contains values in between the specified start and end date
    """

    return df.loc[(df['date'] >= start_date) & (df['date'] <= end_date)].reset_index(drop=True)

# %%
def get_features(df, shift_period, reg_or_clas):

    if reg_or_clas == 'reg':
        # get a list of all the binary price columns needed for the classification analysis
        binary_price_cols_to_drop = list(df.filter(like="binary_price_change", axis=1).columns)

        # get a list of the shifted price columns not needed for this regression analysis
        shifted_cols = list(df.filter(like="shifted", axis=1).columns)
        train_colname = "shifted_{}".format(shift_period)
        shifted_price_cols_to_drop = [col for col in shifted_cols if col != train_colname]

    elif reg_or_clas == 'clas':
        # get a list of the shifted columns needed for the regression analysis
        shifted_price_cols_to_drop = list(df.filter(like="shifted", axis=1).columns)

        # get a list of the shifted binary price columns needed for the classification analysis
        binary_price_cols = list(df.filter(like="binary_price_change", axis=1).columns)
        train_colname = "binary_price_change_{}".format(shift_period)
        binary_price_cols_to_drop = [col for col in binary_price_cols if col != train_colname]

    cols_to_drop = ["date"] + binary_price_cols_to_drop + shifted_price_cols_to_drop

    # drop the features that are not to be used in the pca
    features = df.drop(columns=cols_to_drop)

    return features, cols_to_drop, train_colname

# %%
def use_rand_forest_to_get_feature_importance(reg_or_clas, feature_df, y, random_seed):

    # fit the RFC model
    if reg_or_clas == 'reg':
        rf_final = RandomForestRegressor(random_state=random_seed, n_jobs=-1)
    if reg_or_clas == 'clas':
        rf_final = RandomForestClassifier(random_state=random_seed, n_jobs=-1)
    rf_final.fit(feature_df, y)

    # make a dataframe of the feature importance
    feature_importance_dict = {"feature": feature_df.columns, "importance": rf_final.feature_importances_}
    feature_importance_df = pd.DataFrame(feature_importance_dict).sort_values(["importance"]).reset_index(drop=True)

    return feature_importance_df

# %%
reg_or_clas = "clas"

# %%
# iterate through the intervals
for train_start_date, train_end_date in tqdm(train_intervals_list):
    print("-------------")
    print("Time Interval:", train_start_date, "-->", train_end_date)
    time_interval_str = '{}_to_{}'.format(train_start_date, train_end_date)
    
    # define the train data for this date interval
    train_df = get_subset_of_data(processed_data, train_start_date, train_end_date)

    # drop any features that have Nan's in them
    subset_train_df = drop_nan_cols(train_df)
    
    # iterate over the shift periods and select the features based on this period
    for shift_period in shift_periods_in_days_list:

        # get a dataframe of the data's features
        train_features, train_cols_to_drop, train_colname = get_features(subset_train_df, shift_period, reg_or_clas)
        
        # get a numpy array of the feature we are trying to predict
        y = np.ravel(train_features[train_colname])
        
        # Use random forest to score feature importance
        feature_importance_df = use_rand_forest_to_get_feature_importance(reg_or_clas, train_features.drop(columns=[train_colname]), y, random_seed)

        print(feature_importance_df.to_markdown())
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# -------------
# Time Interval: 2015-08-17 --> 2020-12-31
# Dropping the following 'Nan' columns:
#  ['crypto_index_open', 'crypto_index_high', 'crypto_index_low', 'crypto_index_close', 'johannesburg_exchange_open', 'johannesburg_exchange_high', 'johannesburg_exchange_low', 'johannesburg_exchange_close', 'denmark_gov_debt_all', 'sweden_gov_debt_all']
# |      | feature                                        |   importance |
# |-----:|:-----------------------------------------------|-------------:|
# |    0 | italy_gdp_at_market_prices                     |  0           |
# |    1 | denmark_trust_in_legal_system                  |  0           |
# |    2 | denmark_secondary_house_purchases              |  0           |
# |    3 | euro_19_gdp_at_market_prices                   |  0           |
# |    4 | euro_area_percent_afford_unexpected_expenses   |  0           |
# |    5 | france_gdp_at_market_prices                    |  0           |
# |    6 | denmark_gdp_at_market_prices                   |  0           |
# |    7 | germany_nominal_effective_exchange_rate        |  0           |
# |    8 | france_nominal_effective_exchange_rate         |  0           |
# |    9 | euro_19_percent_afford_unexpected_expenses     |  0           |
# |   10 | italy_nominal_effective_exchange_rate          |  0           |
# |   11 | belgium_trust_in_legal_system                  |  0           |
# |   12 | italy_trust_in_legal_system                    |  0           |
# |   13 | uk_trust_in_legal_system                       |  0           |
# |   14 | belgium_nominal_effective_exchange_rate        |  0           |
# |   15 | denmark_percent_housholds_w_internet           |  0           |
# |   16 | germany_percent_afford_unexpected_expenses     |  0           |
# |   17 | turkey_trust_in_legal_system                   |  0           |
# |   18 | euro_19_producer_industry_prices               |  0           |
# |   19 | france_trust_in_legal_system                   |  0           |
# |   20 | germany_producer_industry_prices               |  0           |
# |   21 | france_percent_afford_unexpected_expenses      |  0           |
# |   22 | belgium_producer_industry_prices               |  0           |
# |   23 | italy_male_healty_life_years                   |  0           |
# |   24 | uk_female_healty_life_years                    |  0           |
# |   25 | italy_female_healty_life_years                 |  0           |
# |   26 | belgium_female_healty_life_years               |  0           |
# |   27 | denmark_female_healty_life_years               |  0           |
# |   28 | sweden_female_healty_life_years                |  0           |
# |   29 | buenos_aires_exchange_volume                   |  0           |
# |   30 | france_male_healty_life_years                  |  0           |
# |   31 | amex_exchange_volume                           |  0           |
# |   32 | uk_house_price_index                           |  0           |
# |   33 | sweden_trust_in_legal_system                   |  0           |
# |   34 | uk_percent_afford_unexpected_expenses          |  0           |
# |   35 | us_gdp                                         |  0           |
# |   36 | france_percent_housholds_w_internet            |  0           |
# |   37 | turkey_percent_housholds_w_internet            |  0           |
# |   38 | turkey_percent_afford_unexpected_expenses      |  0           |
# |   39 | us_prime_loan_rate                             |  0           |
# |   40 | us_long_natural_unemployment_rate              |  0           |
# |   41 | musk_percent_neg                               |  0           |
# |   42 | us_median_house_income                         |  0           |
# |   43 | sweden_housing_price_index                     |  0           |
# |   44 | uk_percent_housholds_w_internet                |  0           |
# |   45 | rank_mtgox                                     |  0           |
# |   46 | us_total_public_debt                           |  0           |
# |   47 | france_gov_debt                                |  0           |
# |   48 | germany_housing_price_index                    |  0           |
# |   49 | germany_trust_in_legal_system                  |  0           |
# |   50 | denmark_percent_afford_unexpected_expenses     |  0           |
# |   51 | france_house_price_index                       |  0           |
# |   52 | denmark_male_healty_life_years                 |  0           |
# |   53 | sweden_harmonised_index_consumer_prices        |  0           |
# |   54 | germany_cpi                                    |  0           |
# |   55 | belgium_percent_afford_unexpected_expenses     |  0           |
# |   56 | italy_housing_price_index                      |  6.30265e-06 |
# |   57 | italy_chain_linked_volumes                     |  1.02795e-05 |
# |   58 | uk_secondary_house_purchases                   |  1.02922e-05 |
# |   59 | denmark_housing_price_index                    |  1.03377e-05 |
# |   60 | germany_job_vacancy_rate                       |  1.03649e-05 |
# |   61 | sweden_percent_afford_unexpected_expenses      |  1.03946e-05 |
# |   62 | belgium_male_healty_life_years                 |  1.04755e-05 |
# |   63 | germany_male_healty_life_years                 |  1.37115e-05 |
# |   64 | euro_19_house_price_index                      |  1.37665e-05 |
# |   65 | sweden_secondary_house_purchases               |  1.37836e-05 |
# |   66 | sweden_services_business_3m_price_expectation  |  1.3889e-05  |
# |   67 | euro_19_housing_price_index                    |  1.39293e-05 |
# |   68 | sweden_gdp_at_market_prices                    |  1.39673e-05 |
# |   69 | sweden_job_vacancy_rate                        |  1.54193e-05 |
# |   70 | belgium_house_price_index                      |  1.54836e-05 |
# |   71 | belgium_percent_housholds_w_internet           |  1.55265e-05 |
# |   72 | us_real_pot_gdp                                |  1.55919e-05 |
# |   73 | france_cpi                                     |  1.65794e-05 |
# |   74 | belgium_services_business_3m_price_expectation |  1.73451e-05 |
# |   75 | germany_female_healty_life_years               |  1.7514e-05  |
# |   76 | denmark_producer_industry_prices               |  1.75369e-05 |
# |   77 | uk_housing_price_index                         |  1.75627e-05 |
# |   78 | belgium_gov_debt                               |  1.78407e-05 |
# |   79 | sweden_producer_industry_prices                |  1.79821e-05 |
# |   80 | germany_house_price_index                      |  1.80349e-05 |
# |   81 | us_cpi                                         |  1.81148e-05 |
# |   82 | us_velocity_m2_money                           |  1.86317e-05 |
# |   83 | italy_percent_housholds_w_internet             |  1.87047e-05 |
# |   84 | canada_cpi                                     |  1.883e-05   |
# |   85 | euro_area_house_price_index                    |  1.88992e-05 |
# |   86 | sweden_male_healty_life_years                  |  1.91146e-05 |
# |   87 | musk_num_neg_tweets                            |  1.93697e-05 |
# |   88 | france_female_healty_life_years                |  2.01038e-05 |
# |   89 | turkey_chain_linked_volumes                    |  2.0173e-05  |
# |   90 | euro_area_housing_price_index                  |  2.07744e-05 |
# |   91 | sin_dotm                                       |  2.25216e-05 |
# |   92 | us_short_natural_unemployment_rate             |  2.60435e-05 |
# |   93 | uk_business_employment_expectation             |  2.76327e-05 |
# |   94 | uk_male_healty_life_years                      |  2.76553e-05 |
# |   95 | us_total_disposble_income                      |  2.76865e-05 |
# |   96 | sweden_day_to_day_interest_rate                |  2.78129e-05 |
# |   97 | us_tot_personal_consumption_spend_dg           |  2.86268e-05 |
# |   98 | germany_secondary_house_purchases              |  2.88675e-05 |
# |   99 | us_cpi_no_food_and_energy                      |  2.94448e-05 |
# |  100 | sweden_percent_housholds_w_internet            |  2.94614e-05 |
# |  101 | belgium_secondary_house_purchases              |  3.15052e-05 |
# |  102 | us_corporate_profit_aftr_tax                   |  3.19767e-05 |
# |  103 | germany_percent_housholds_w_internet           |  3.21678e-05 |
# |  104 | russia_cpi                                     |  3.22036e-05 |
# |  105 | france_producer_industry_prices                |  3.26066e-05 |
# |  106 | france_housing_price_index                     |  3.29463e-05 |
# |  107 | uk_cpi                                         |  3.33013e-05 |
# |  108 | turkey_secondary_house_purchases               |  3.38062e-05 |
# |  109 | turkey_nominal_effective_exchange_rate         |  3.44606e-05 |
# |  110 | sweden_gov_debt                                |  3.52865e-05 |
# |  111 | belgium_housing_price_index                    |  3.54434e-05 |
# |  112 | france_secondary_house_purchases               |  3.56759e-05 |
# |  113 | us_harmonised_index_consumer_prices            |  3.76329e-05 |
# |  114 | musk_percent_neut                              |  3.84282e-05 |
# |  115 | musk_num_neut_tweets                           |  3.95214e-05 |
# |  116 | sweden_house_price_index                       |  4.01196e-05 |
# |  117 | musk_num_pos_tweets                            |  4.40674e-05 |
# |  118 | uk_harmonised_index_consumer_prices            |  4.6503e-05  |
# |  119 | turkey_harmonised_index_consumer_prices        |  4.66685e-05 |
# |  120 | us_new_housing_devs_started                    |  4.763e-05   |
# |  121 | us_gdp_ipd                                     |  4.77659e-05 |
# |  122 | germany_gdp_at_market_prices                   |  4.78096e-05 |
# |  123 | turkey_housing_price_index                     |  4.96889e-05 |
# |  124 | turkey_house_price_index                       |  5.11363e-05 |
# |  125 | russia_nominal_effective_exchange_rate         |  5.18921e-05 |
# |  126 | euro_19_consumer_confidence_indicator          |  5.45289e-05 |
# |  127 | sweden_consumer_confidence_indicator           |  5.5839e-05  |
# |  128 | difficulty14rsi                                |  5.61607e-05 |
# |  129 | denmark_harmonised_index_consumer_prices       |  5.63977e-05 |
# |  130 | denmark_services_business_3m_price_expectation |  5.96326e-05 |
# |  131 | denmark_house_price_index                      |  6.12133e-05 |
# |  132 | turkey_cpi                                     |  6.17716e-05 |
# |  133 | us_tot_personal_consumption_spend              |  6.2294e-05  |
# |  134 | denmark_industry_production                    |  6.2425e-05  |
# |  135 | us_num_unemployed                              |  6.2938e-05  |
# |  136 | canada_nominal_effective_exchange_rate         |  6.4262e-05  |
# |  137 | marketcap7sma                                  |  6.81298e-05 |
# |  138 | us_cpi_all                                     |  6.86116e-05 |
# |  139 | italy_percent_afford_unexpected_expenses       |  7.22012e-05 |
# |  140 | uk_producer_industry_prices                    |  7.29273e-05 |
# |  141 | musk_percent_pos                               |  7.33082e-05 |
# |  142 | belgium_harmonised_index_consumer_prices       |  7.59798e-05 |
# |  143 | china_and_hk_nominal_effective_exchange_rate   |  7.60806e-05 |
# |  144 | difficulty7sma                                 |  7.75886e-05 |
# |  145 | denmark_gov_debt                               |  7.8893e-05  |
# |  146 | euro_19_retail_business_sales_confidence       |  8.08436e-05 |
# |  147 | germany_harmonised_index_consumer_prices       |  8.18489e-05 |
# |  148 | us_total_real_disposable_income                |  8.39966e-05 |
# |  149 | dow_jones_close                                |  8.47639e-05 |
# |  150 | euro_19_harmonised_index_consumer_prices       |  8.5952e-05  |
# |  151 | euro_area_day_to_day_interest_rate             |  9.22108e-05 |
# |  152 | mining_profitability90var                      |  9.23726e-05 |
# |  153 | euro_19_business_employment_expectation        |  9.63558e-05 |
# |  154 | italy_cpi                                      |  9.70125e-05 |
# |  155 | us_velocity_m1_money                           |  9.76633e-05 |
# |  156 | us_leading_index                               |  9.89952e-05 |
# |  157 | euro_19_current_account_balance                |  9.93803e-05 |
# |  158 | sweden_nominal_effective_exchange_rate         |  0.000101087 |
# |  159 | price90sma                                     |  0.000101678 |
# |  160 | us_m1_money                                    |  0.000103607 |
# |  161 | us_percent_personal_saving_rate                |  0.000104743 |
# |  162 | china_and_hk_cpi                               |  0.000104986 |
# |  163 | us_public_debt_as_perc_of_gdp                  |  0.000112933 |
# |  164 | turkey_retail_business_sales_confidence        |  0.000115744 |
# |  165 | south_korea_nominal_effective_exchange_rate    |  0.000116235 |
# |  166 | us_monetart_base                               |  0.000117236 |
# |  167 | belgium_gdp_at_market_prices                   |  0.000118946 |
# |  168 | hashrate30wma                                  |  0.000120435 |
# |  169 | euro_19_gov_debt                               |  0.000120633 |
# |  170 | us_30_year_be_inflation_rate                   |  0.000121633 |
# |  171 | japan_government_10_yr_bonds                   |  0.000123059 |
# |  172 | italy_industry_production                      |  0.000124416 |
# |  173 | median_transaction_fee90ema                    |  0.000125982 |
# |  174 | italy_consumer_confidence_indicator            |  0.000127517 |
# |  175 | us_labour_force_employ_rate                    |  0.000128784 |
# |  176 | italy_producer_industry_prices                 |  0.000129019 |
# |  177 | uk_industry_production                         |  0.000130655 |
# |  178 | euro_area_harmonised_index_consumer_prices     |  0.000133027 |
# |  179 | difficulty90rsi                                |  0.000133945 |
# |  180 | cos_dotm                                       |  0.000135053 |
# |  181 | transactionvalue90ema                          |  0.000139513 |
# |  182 | germany_retail_business_sales_confidence       |  0.000140607 |
# |  183 | us_capacity_utilisation                        |  0.0001421   |
# |  184 | us_gross_private_domestic_investment           |  0.00014656  |
# |  185 | south_korea_cpi                                |  0.00014878  |
# |  186 | difficulty3rsi                                 |  0.000150744 |
# |  187 | transactionfees90ema                           |  0.000152754 |
# |  188 | difficulty90ema                                |  0.00015299  |
# |  189 | us_nominal_effective_exchange_rate             |  0.000153664 |
# |  190 | transactionfees30wma                           |  0.000154015 |
# |  191 | price90ema                                     |  0.000155735 |
# |  192 | denmark_consumer_confidence_indicator          |  0.000157423 |
# |  193 | belgium_business_employment_expectation        |  0.00015772  |
# |  194 | us_cpi_no_food_and_energy_perc_change          |  0.000157879 |
# |  195 | sweden_retail_business_sales_confidence        |  0.000159542 |
# |  196 | us_real_retail_and_food_sales                  |  0.000160007 |
# |  197 | median_transaction_fee7sma                     |  0.000160543 |
# |  198 | us_bank_excess_capital_reserves                |  0.000161425 |
# |  199 | turkey_day_to_day_interest_rate                |  0.000162083 |
# |  200 | us_government_10_yr_bonds                      |  0.000164093 |
# |  201 | sp_500_low                                     |  0.000164187 |
# |  202 | turkey_business_employment_expectation         |  0.000166714 |
# |  203 | sentinusd14sma                                 |  0.0001679   |
# |  204 | difficulty90std                                |  0.000167916 |
# |  205 | sweden_industry_production                     |  0.00016932  |
# |  206 | us_industry_production_index                   |  0.000173134 |
# |  207 | marketcap90ema                                 |  0.000173617 |
# |  208 | turkey_industry_production                     |  0.000174463 |
# |  209 | mining_profitability14var                      |  0.00017744  |
# |  210 | difficulty90wma                                |  0.000177933 |
# |  211 | germany_consumer_confidence_indicator          |  0.000180276 |
# |  212 | denmark_retail_business_sales_confidence       |  0.000181452 |
# |  213 | belgium_retail_business_sales_confidence       |  0.000182702 |
# |  214 | italy_services_business_3m_price_expectation   |  0.000183087 |
# |  215 | usd_eur_exchange_low                           |  0.000184389 |
# |  216 | hashrate30ema                                  |  0.000184685 |
# |  217 | germany_business_employment_expectation        |  0.000184987 |
# |  218 | us_real_GDP                                    |  0.00018617  |
# |  219 | turkey_government_10_yr_bonds                  |  0.000187158 |
# |  220 | denmark_nominal_effective_exchange_rate        |  0.000187207 |
# |  221 | hashrate90wma                                  |  0.00018816  |
# |  222 | top100cap30var                                 |  0.000191191 |
# |  223 | japan_nominal_effective_exchange_rate          |  0.000192502 |
# |  224 | price90trx                                     |  0.000194835 |
# |  225 | sentinusd30wma                                 |  0.000197267 |
# |  226 | italy_retail_business_sales_confidence         |  0.000198486 |
# |  227 | median_transaction_fee30std                    |  0.000198888 |
# |  228 | marketcap90sma                                 |  0.000200088 |
# |  229 | sweden_business_employment_expectation         |  0.000200309 |
# |  230 | median_transaction_fee30ema                    |  0.000200647 |
# |  231 | france_services_business_3m_price_expectation  |  0.000200817 |
# |  232 | buenos_aires_exchange_low                      |  0.00020089  |
# |  233 | transactionfees30ema                           |  0.000200929 |
# |  234 | france_harmonised_index_consumer_prices        |  0.000202009 |
# |  235 | activeaddresses90ema                           |  0.00020231  |
# |  236 | hashrate14ema                                  |  0.000202438 |
# |  237 | mining_profitability30wma                      |  0.000206719 |
# |  238 | hashrate7sma                                   |  0.000206792 |
# |  239 | transactionfees30sma                           |  0.000207382 |
# |  240 | mining_profitability30sma                      |  0.000207421 |
# |  241 | size14var                                      |  0.000208068 |
# |  242 | germany_industry_production                    |  0.00020969  |
# |  243 | price3wma                                      |  0.000212011 |
# |  244 | palladium_futures_low                          |  0.00021286  |
# |  245 | price90wma                                     |  0.000214613 |
# |  246 | price30var                                     |  0.000216169 |
# |  247 | nasdaq_exchange_volume                         |  0.000217346 |
# |  248 | us_20_year_be_inflation_rate                   |  0.000218865 |
# |  249 | france_retail_business_sales_confidence        |  0.000219825 |
# |  250 | difficulty30rsi                                |  0.000221092 |
# |  251 | marketcap3wma                                  |  0.000222359 |
# |  252 | fee_to_reward90ema                             |  0.000222927 |
# |  253 | france_chain_linked_volumes                    |  0.00022404  |
# |  254 | palladium_futures_close                        |  0.000224669 |
# |  255 | top100cap90sma                                 |  0.000226112 |
# |  256 | germany_services_business_3m_price_expectation |  0.000226511 |
# |  257 | us_m2_money                                    |  0.000226871 |
# |  258 | euro_19_services_business_3m_price_expectation |  0.000228207 |
# |  259 | turkey_consumer_confidence_indicator           |  0.000229702 |
# |  260 | transactionfees90wma                           |  0.00023022  |
# |  261 | eur_chf_exchange_close                         |  0.00023295  |
# |  262 | transactionfees90var                           |  0.000232988 |
# |  263 | transactionfees30var                           |  0.000233747 |
# |  264 | difficulty3sma                                 |  0.000234715 |
# |  265 | us_num_filing_for_unemployment                 |  0.000236288 |
# |  266 | difficulty14wma                                |  0.000237023 |
# |  267 | us_pop_employ_rate                             |  0.000238532 |
# |  268 | transactionfees3wma                            |  0.000241092 |
# |  269 | transactions7wma                               |  0.000244023 |
# |  270 | us_nonfarm_num_employed                        |  0.000244703 |
# |  271 | median_transaction_fee30sma                    |  0.000245694 |
# |  272 | euro_19_industry_production                    |  0.000246644 |
# |  273 | top100cap30ema                                 |  0.000247097 |
# |  274 | new_york_exchange_high                         |  0.000247658 |
# |  275 | hashrate7ema                                   |  0.000249967 |
# |  276 | france_industry_production                     |  0.000250444 |
# |  277 | nasdaq_exchange_close                          |  0.000250751 |
# |  278 | musk_num_tweets                                |  0.000252288 |
# |  279 | median_transaction_fee90var                    |  0.000252763 |
# |  280 | sentinusd14wma                                 |  0.00025721  |
# |  281 | median_transaction_fee3ema                     |  0.000258782 |
# |  282 | santiago_exchange_low                          |  0.000259364 |
# |  283 | median_transaction_fee90sma                    |  0.000259414 |
# |  284 | fee_to_reward90var                             |  0.000259716 |
# |  285 | hashrate30trx                                  |  0.000262046 |
# |  286 | mining_profitability3var                       |  0.000262535 |
# |  287 | italy_harmonised_index_consumer_prices         |  0.000262936 |
# |  288 | us_fed_funds_rate                              |  0.000264046 |
# |  289 | median_transaction_fee14std                    |  0.000266378 |
# |  290 | mining_profitability7var                       |  0.000266921 |
# |  291 | uk_retail_business_sales_confidence            |  0.00026734  |
# |  292 | uk_nominal_effective_exchange_rate             |  0.000268239 |
# |  293 | nasdaq_exchange_high                           |  0.000268514 |
# |  294 | nasdaq_exchange_open                           |  0.000269919 |
# |  295 | median_transaction_fee7std                     |  0.000271485 |
# |  296 | transactionfees90std                           |  0.000274343 |
# |  297 | us_total_commercial_loans                      |  0.000276255 |
# |  298 | us_median_cpi                                  |  0.000277027 |
# |  299 | mining_profitability90wma                      |  0.000279274 |
# |  300 | italy_house_price_index                        |  0.000283093 |
# |  301 | transactionvalue30sma                          |  0.0002837   |
# |  302 | hong_kong_hang_seng_low                        |  0.000285198 |
# |  303 | japan_cpi                                      |  0.000287182 |
# |  304 | activeaddresses90trx                           |  0.000287624 |
# |  305 | mediantransactionvalue30ema                    |  0.00028905  |
# |  306 | uk_emu_convergence_bond_yield                  |  0.000289055 |
# |  307 | google_trends30std                             |  0.000291035 |
# |  308 | santiago_exchange_high                         |  0.000291129 |
# |  309 | mediantransactionvalue30wma                    |  0.000292135 |
# |  310 | all_euro_forward_yields_M3                     |  0.000296123 |
# |  311 | difficulty30wma                                |  0.000298276 |
# |  312 | google_trends90std                             |  0.000301894 |
# |  313 | indonesia_exchange_low                         |  0.000302613 |
# |  314 | median_transaction_fee14sma                    |  0.000302724 |
# |  315 | uk_consumer_confidence_indicator               |  0.000302913 |
# |  316 | transactionfees7ema                            |  0.000303682 |
# |  317 | cos_dotw                                       |  0.000304081 |
# |  318 | activeaddresses3wma                            |  0.000304241 |
# |  319 | mediantransactionvalue14sma                    |  0.000308266 |
# |  320 | denmark_business_employment_expectation        |  0.000309261 |
# |  321 | transactionfees14ema                           |  0.000310615 |
# |  322 | mediantransactionvalue14wma                    |  0.000310847 |
# |  323 | difficulty90sma                                |  0.000311452 |
# |  324 | median_transaction_fee30var                    |  0.000311964 |
# |  325 | us_10_year_be_inflation_rate                   |  0.000315424 |
# |  326 | marketcap30sma                                 |  0.000316812 |
# |  327 | french_cac_40_close                            |  0.000317317 |
# |  328 | median_transaction_fee3wma                     |  0.000318376 |
# |  329 | italy_gov_debt                                 |  0.000318989 |
# |  330 | euro_area_emu_convergence_bond_yield           |  0.0003206   |
# |  331 | hashrate90sma                                  |  0.000321882 |
# |  332 | italy_business_employment_expectation          |  0.000322233 |
# |  333 | us_unemployment_rate                           |  0.000322378 |
# |  334 | transactionfees14var                           |  0.000322982 |
# |  335 | germany_gov_debt                               |  0.00032373  |
# |  336 | transactionfees14sma                           |  0.000326313 |
# |  337 | mediantransactionvalue30std                    |  0.000328749 |
# |  338 | santiago_exchange_open                         |  0.000329799 |
# |  339 | fee_to_reward90std                             |  0.000330213 |
# |  340 | aluminium_futures_open                         |  0.000330668 |
# |  341 | sp_500_close                                   |  0.000331316 |
# |  342 | all_euro_forward_yields_Y10                    |  0.000332959 |
# |  343 | usd_mxn_exchange_close                         |  0.000333861 |
# |  344 | transactionfees3sma                            |  0.000334029 |
# |  345 | median_transaction_fee7var                     |  0.000334201 |
# |  346 | sentinusd90sma                                 |  0.000336369 |
# |  347 | top100cap7sma                                  |  0.000336513 |
# |  348 | mediantransactionvalue90trx                    |  0.000336964 |
# |  349 | mining_profitability30var                      |  0.000338196 |
# |  350 | sentbyaddress14sma                             |  0.000338811 |
# |  351 | uk_day_to_day_interest_rate                    |  0.000339469 |
# |  352 | copper_futures_open                            |  0.000340277 |
# |  353 | size90ema                                      |  0.000340419 |
# |  354 | activeaddresses30trx                           |  0.000340578 |
# |  355 | hashrate90var                                  |  0.000341762 |
# |  356 | australian_exchange_open                       |  0.000342088 |
# |  357 | irish_exchange_close                           |  0.000345281 |
# |  358 | difficulty30trx                                |  0.000348991 |
# |  359 | median_transaction_fee30mom                    |  0.000350323 |
# |  360 | denmark_emu_convergence_bond_yield             |  0.000350341 |
# |  361 | difficulty3wma                                 |  0.000350885 |
# |  362 | google_trends30ema                             |  0.000351081 |
# |  363 | marketcap7wma                                  |  0.000352486 |
# |  364 | size14wma                                      |  0.000353992 |
# |  365 | difficulty14sma                                |  0.000354367 |
# |  366 | sentinusd90std                                 |  0.000354475 |
# |  367 | denmark_day_to_day_interest_rate               |  0.000355339 |
# |  368 | crude_oil_futures_high                         |  0.000355539 |
# |  369 | difficulty7ema                                 |  0.000358793 |
# |  370 | activeaddresses14wma                           |  0.000361263 |
# |  371 | belgium_emu_convergence_bond_yield             |  0.000361958 |
# |  372 | mining_profitability14wma                      |  0.00036212  |
# |  373 | german_dax_low                                 |  0.000362281 |
# |  374 | fee_to_reward30std                             |  0.000364601 |
# |  375 | mediantransactionvalue7wma                     |  0.000364656 |
# |  376 | mediantransactionvalue7sma                     |  0.000365513 |
# |  377 | singapore_exchange_low                         |  0.000365779 |
# |  378 | median_transaction_fee90std                    |  0.000366106 |
# |  379 | size90wma                                      |  0.000366453 |
# |  380 | mediantransactionvalue90wma                    |  0.000367142 |
# |  381 | transactionfees90sma                           |  0.00036793  |
# |  382 | sentbyaddress90sma                             |  0.000367936 |
# |  383 | fee_to_reward30wma                             |  0.000369562 |
# |  384 | median_transaction_fee30wma                    |  0.00036992  |
# |  385 | price3sma                                      |  0.000370817 |
# |  386 | top100cap7wma                                  |  0.000372948 |
# |  387 | google_trends14sma                             |  0.000373324 |
# |  388 | marketcap90wma                                 |  0.000373793 |
# |  389 | marketcap7ema                                  |  0.000376093 |
# |  390 | price7ema                                      |  0.000376539 |
# |  391 | palladium_futures_open                         |  0.000377422 |
# |  392 | difficulty14mom                                |  0.000377966 |
# |  393 | difficulty7rsi                                 |  0.00037904  |
# |  394 | australia_asx_200_volume                       |  0.000379563 |
# |  395 | marketcap30wma                                 |  0.000380599 |
# |  396 | sentbyaddress3wma                              |  0.00038099  |
# |  397 | sentinusd90wma                                 |  0.000381394 |
# |  398 | mexican_exchange_low                           |  0.000381801 |
# |  399 | price14wma                                     |  0.000381975 |
# |  400 | transactionfees7wma                            |  0.000382457 |
# |  401 | top100cap30trx                                 |  0.000383226 |
# |  402 | japan_nikkei_225_close                         |  0.000383436 |
# |  403 | hashrate14wma                                  |  0.000383679 |
# |  404 | italy_secondary_house_purchases                |  0.000385472 |
# |  405 | google_trends3wma                              |  0.000385902 |
# |  406 | mining_profitability30ema                      |  0.000386521 |
# |  407 | google_trends90sma                             |  0.000386831 |
# |  408 | fee_to_reward30var                             |  0.000387018 |
# |  409 | belgium_20_low                                 |  0.000388308 |
# |  410 | us_5_year_be_inflation_rate                    |  0.000388448 |
# |  411 | korean_kospi_low                               |  0.000388732 |
# |  412 | mining_profitability7wma                       |  0.000391403 |
# |  413 | sp_500_high                                    |  0.000391663 |
# |  414 | top100cap90trx                                 |  0.000392901 |
# |  415 | fee_to_reward30ema                             |  0.000393286 |
# |  416 | sentinusd90roc                                 |  0.000394139 |
# |  417 | new_york_exchange_low                          |  0.000395007 |
# |  418 | us_ted_spread                                  |  0.000395174 |
# |  419 | difficulty7wma                                 |  0.000396008 |
# |  420 | activeaddresses90wma                           |  0.000396023 |
# |  421 | usd_aud_exchange_high                          |  0.000396283 |
# |  422 | french_cac_40_open                             |  0.00039745  |
# |  423 | santiago_exchange_close                        |  0.000399503 |
# |  424 | vix_low                                        |  0.000401332 |
# |  425 | marketcap30ema                                 |  0.000401661 |
# |  426 | difficulty30sma                                |  0.000403532 |
# |  427 | france_consumer_confidence_indicator           |  0.000404034 |
# |  428 | rank_btce                                      |  0.000404954 |
# |  429 | marketcap14wma                                 |  0.000407778 |
# |  430 | sentinusd30std                                 |  0.000407957 |
# |  431 | transactionfees14wma                           |  0.000407996 |
# |  432 | turkey_services_business_3m_price_expectation  |  0.000408284 |
# |  433 | all_euro_spot_yields_Y2                        |  0.000408785 |
# |  434 | google_trends7ema                              |  0.000409214 |
# |  435 | toronto_exchange_open                          |  0.000411068 |
# |  436 | eur_chf_exchange_high                          |  0.000411587 |
# |  437 | italy_emu_convergence_bond_yield               |  0.000412069 |
# |  438 | mining_profitability90sma                      |  0.000412118 |
# |  439 | buenos_aires_exchange_open                     |  0.000412861 |
# |  440 | hashrate90ema                                  |  0.000413554 |
# |  441 | live_cattle_futures_close                      |  0.00041456  |
# |  442 | cotton_futures_close                           |  0.000414839 |
# |  443 | corn_futures_volume                            |  0.000414882 |
# |  444 | australia_asx_200_high                         |  0.000415249 |
# |  445 | top100cap14sma                                 |  0.000415503 |
# |  446 | buenos_aires_exchange_close                    |  0.000416434 |
# |  447 | belgium_consumer_confidence_indicator          |  0.000418132 |
# |  448 | transactionvalue90var                          |  0.000418522 |
# |  449 | usd_jpy_exchange_open                          |  0.000419166 |
# |  450 | japan_nikkei_225_low                           |  0.000420252 |
# |  451 | sentbyaddress14var                             |  0.000421081 |
# |  452 | copper_futures_close                           |  0.000421382 |
# |  453 | difficulty30ema                                |  0.00042297  |
# |  454 | mediantransactionvalue30sma                    |  0.00042316  |
# |  455 | dow_jones_high                                 |  0.000426772 |
# |  456 | top100cap90wma                                 |  0.000428724 |
# |  457 | top100cap3sma                                  |  0.000429141 |
# |  458 | transactions90ema                              |  0.000429405 |
# |  459 | australia_asx_200_close                        |  0.000430073 |
# |  460 | taiwan_exchange_low                            |  0.000430383 |
# |  461 | difficulty30roc                                |  0.000432653 |
# |  462 | size7sma                                       |  0.000432751 |
# |  463 | australian_exchange_close                      |  0.000433094 |
# |  464 | eur_chf_exchange_open                          |  0.000433397 |
# |  465 | aluminium_futures_high                         |  0.000435099 |
# |  466 | top100cap14wma                                 |  0.000436599 |
# |  467 | belgium_industry_production                    |  0.000437452 |
# |  468 | transactionfees30std                           |  0.000437689 |
# |  469 | turkey_bist_100_high                           |  0.000438147 |
# |  470 | difficulty90trx                                |  0.000438345 |
# |  471 | germany_emu_convergence_bond_yield             |  0.00043838  |
# |  472 | hashrate30sma                                  |  0.000439084 |
# |  473 | sweden_emu_convergence_bond_yield              |  0.000439181 |
# |  474 | toronto_exchange_volume                        |  0.000441374 |
# |  475 | activeaddresses14trx                           |  0.000443534 |
# |  476 | spain_ibex_30_close                            |  0.000443645 |
# |  477 | sentinusd30sma                                 |  0.000444074 |
# |  478 | sin_dotw                                       |  0.000444101 |
# |  479 | size30wma                                      |  0.000445166 |
# |  480 | google_trends90trx                             |  0.0004456   |
# |  481 | activeaddresses30sma                           |  0.000445756 |
# |  482 | sentinusd7ema                                  |  0.000446132 |
# |  483 | belgium_20_volume                              |  0.000446279 |
# |  484 | indonesia_exchange_close                       |  0.000446422 |
# |  485 | sentinusd3ema                                  |  0.00044741  |
# |  486 | sugar_futures_low                              |  0.000447978 |
# |  487 | activeaddresses3ema                            |  0.0004481   |
# |  488 | hashrate30std                                  |  0.000448184 |
# |  489 | fee_to_reward90wma                             |  0.000448806 |
# |  490 | eur_jpy_exchange_close                         |  0.000450211 |
# |  491 | gbp_jyp_exchange_open                          |  0.00045024  |
# |  492 | price                                          |  0.00045027  |
# |  493 | confirmationtime90trx                          |  0.000450875 |
# |  494 | palladium_futures_volume                       |  0.000452246 |
# |  495 | taiwan_exchange_close                          |  0.00045254  |
# |  496 | marketcap3sma                                  |  0.000452637 |
# |  497 | nasdaq_exchange_low                            |  0.000455353 |
# |  498 | top100cap3wma                                  |  0.000457744 |
# |  499 | irish_exchange_high                            |  0.000462179 |
# |  500 | hashrate14sma                                  |  0.000463062 |
# |  501 | all_euro_spot_yields_Y5                        |  0.000464647 |
# |  502 | hashrate3ema                                   |  0.00046517  |
# |  503 | transactions14ema                              |  0.00046545  |
# |  504 | top100cap7var                                  |  0.000469318 |
# |  505 | price30wma                                     |  0.000469821 |
# |  506 | median_transaction_fee90wma                    |  0.000470342 |
# |  507 | sentbyaddress90trx                             |  0.000470685 |
# |  508 | france_business_employment_expectation         |  0.000471527 |
# |  509 | price30ema                                     |  0.000471928 |
# |  510 | transactionvalue90trx                          |  0.000472684 |
# |  511 | australia_asx_200_low                          |  0.000473141 |
# |  512 | gold_futures_high                              |  0.000474004 |
# |  513 | sentbyaddress30ema                             |  0.0004761   |
# |  514 | difficulty3ema                                 |  0.000476387 |
# |  515 | mining_profitability7sma                       |  0.000476446 |
# |  516 | crude_oil_futures_close                        |  0.000476561 |
# |  517 | all_euro_forward_yields_Y1                     |  0.000476975 |
# |  518 | tweets90wma                                    |  0.000477751 |
# |  519 | confirmationtime90wma                          |  0.000478718 |
# |  520 | vix_close                                      |  0.000478742 |
# |  521 | usd_jpy_exchange_low                           |  0.000479128 |
# |  522 | sentbyaddress3ema                              |  0.000479365 |
# |  523 | marketcap14var                                 |  0.000483228 |
# |  524 | hashrate7wma                                   |  0.000483251 |
# |  525 | hashrate7var                                   |  0.000483465 |
# |  526 | all_euro_spot_yields_Y10                       |  0.000485063 |
# |  527 | price14ema                                     |  0.000485223 |
# |  528 | marketcap3ema                                  |  0.000486214 |
# |  529 | google_trends14ema                             |  0.000487926 |
# |  530 | mining_profitability14std                      |  0.000490282 |
# |  531 | fee_to_reward30sma                             |  0.000490838 |
# |  532 | top100cap90ema                                 |  0.000491748 |
# |  533 | marketcap14ema                                 |  0.0004919   |
# |  534 | mediantransactionvalue14trx                    |  0.000492948 |
# |  535 | oat_futures_low                                |  0.000493081 |
# |  536 | taiwan_exchange_open                           |  0.000493243 |
# |  537 | tweets7ema                                     |  0.000494901 |
# |  538 | rank_okcoin                                    |  0.00049543  |
# |  539 | usd_hkd_exchange_high                          |  0.00049694  |
# |  540 | mediantransactionvalue14ema                    |  0.000497243 |
# |  541 | hashrate                                       |  0.000497616 |
# |  542 | google_trends14var                             |  0.000499005 |
# |  543 | difficulty90roc                                |  0.000500941 |
# |  544 | transactionvalue14wma                          |  0.000501663 |
# |  545 | google_trends7std                              |  0.000502074 |
# |  546 | top100cap90mom                                 |  0.000502168 |
# |  547 | rank_others                                    |  0.000502458 |
# |  548 | live_cattle_futures_low                        |  0.000502477 |
# |  549 | confirmationtime90var                          |  0.000503095 |
# |  550 | transactionvalue90wma                          |  0.000503646 |
# |  551 | transactions7ema                               |  0.000505203 |
# |  552 | vix_high                                       |  0.000505708 |
# |  553 | indonesia_exchange_high                        |  0.000508081 |
# |  554 | mediantransactionvalue90ema                    |  0.000510977 |
# |  555 | price30sma                                     |  0.00051177  |
# |  556 | transactionvalue30ema                          |  0.000511781 |
# |  557 | sentinusd14trx                                 |  0.000515131 |
# |  558 | irish_exchange_low                             |  0.00051622  |
# |  559 | new_york_exchange_close                        |  0.000517156 |
# |  560 | median_transaction_fee7wma                     |  0.000517304 |
# |  561 | median_transaction_fee14wma                    |  0.000519162 |
# |  562 | mining_profitability7ema                       |  0.000520795 |
# |  563 | mining_profitability90std                      |  0.00052108  |
# |  564 | sentinusd90ema                                 |  0.000522662 |
# |  565 | activeaddresses30wma                           |  0.000523484 |
# |  566 | mining_profitability90ema                      |  0.00052359  |
# |  567 | sentbyaddress90var                             |  0.000523717 |
# |  568 | block_size_votes                               |  0.000524376 |
# |  569 | all_euro_spot_yields_M6                        |  0.000524664 |
# |  570 | gbp_jyp_exchange_close                         |  0.000525971 |
# |  571 | marketcap14sma                                 |  0.000526526 |
# |  572 | mining_profitability3std                       |  0.00052796  |
# |  573 | fee_to_reward90sma                             |  0.00052893  |
# |  574 | marketcap90std                                 |  0.000528982 |
# |  575 | corn_futures_close                             |  0.000529265 |
# |  576 | google_trends30wma                             |  0.000530968 |
# |  577 | median_transaction_fee3sma                     |  0.000531571 |
# |  578 | activeaddresses7sma                            |  0.000531593 |
# |  579 | tweets90sma                                    |  0.000532749 |
# |  580 | activeaddresses90std                           |  0.00053298  |
# |  581 | median_transaction_fee14var                    |  0.000533201 |
# |  582 | transactions3ema                               |  0.000533997 |
# |  583 | hashrate14var                                  |  0.000535322 |
# |  584 | usd_hkd_exchange_close                         |  0.000535962 |
# |  585 | google_trends90ema                             |  0.000536443 |
# |  586 | all_euro_forward_yields_M6                     |  0.000536562 |
# |  587 | price90var                                     |  0.000536642 |
# |  588 | euronext_100_euro_volume                       |  0.00053714  |
# |  589 | taiwan_exchange_volume                         |  0.000537424 |
# |  590 | mining_profitability3ema                       |  0.000537801 |
# |  591 | usd_mxn_exchange_open                          |  0.000538444 |
# |  592 | indonesia_exchange_volume                      |  0.000538577 |
# |  593 | price90std                                     |  0.000539428 |
# |  594 | mining_profitability3sma                       |  0.000539613 |
# |  595 | mining_profitability90trx                      |  0.0005403   |
# |  596 | us_financial_stress_index                      |  0.000540494 |
# |  597 | copper_futures_low                             |  0.000540611 |
# |  598 | sentinusd                                      |  0.000540668 |
# |  599 | german_dax_volume                              |  0.000540884 |
# |  600 | tweets                                         |  0.000541705 |
# |  601 | spain_ibex_30_open                             |  0.000542016 |
# |  602 | difficulty30mom                                |  0.000542181 |
# |  603 | transactions14sma                              |  0.000542976 |
# |  604 | median_transaction_fee3var                     |  0.000543025 |
# |  605 | usd_aud_exchange_close                         |  0.000543249 |
# |  606 | gold_futures_close                             |  0.00054404  |
# |  607 | top100cap14ema                                 |  0.000544134 |
# |  608 | transactionfees7sma                            |  0.000545342 |
# |  609 | sentinusd90trx                                 |  0.000546142 |
# |  610 | activeaddresses30ema                           |  0.000546305 |
# |  611 | lumber_futures_low                             |  0.000547348 |
# |  612 | aluminium_futures_low                          |  0.000547969 |
# |  613 | toronto_exchange_low                           |  0.000548428 |
# |  614 | mediantransactionvalue90sma                    |  0.000548957 |
# |  615 | mediantransactionvalue90std                    |  0.000550358 |
# |  616 | taiwan_exchange_high                           |  0.000550426 |
# |  617 | fee_to_reward7ema                              |  0.000551931 |
# |  618 | us_5_year_treasury_const_mat_rate              |  0.000552297 |
# |  619 | us_5_year_yield                                |  0.000552787 |
# |  620 | usd_hkd_exchange_open                          |  0.000552878 |
# |  621 | transactions90sma                              |  0.000554696 |
# |  622 | mediantransactionvalue3sma                     |  0.000554868 |
# |  623 | google_trends90rsi                             |  0.000556323 |
# |  624 | euronext_100_euro_close                        |  0.000557806 |
# |  625 | natural_gas_futures_low                        |  0.000558242 |
# |  626 | sentbyaddress90ema                             |  0.000558555 |
# |  627 | usd_eur_exchange_open                          |  0.000561541 |
# |  628 | sp_500_open                                    |  0.000564217 |
# |  629 | eur_gbp_exchange_close                         |  0.000564493 |
# |  630 | uk_services_business_3m_price_expectation      |  0.000564715 |
# |  631 | us_broad_trade_weighted_dollar_index           |  0.000566747 |
# |  632 | median_transaction_fee                         |  0.00056833  |
# |  633 | aluminium_futures_volume                       |  0.000569166 |
# |  634 | hong_kong_hang_seng_open                       |  0.000570177 |
# |  635 | google_trends30trx                             |  0.000570618 |
# |  636 | tweets90trx                                    |  0.000571772 |
# |  637 | transactionfees3ema                            |  0.0005724   |
# |  638 | rough_rice_futures_close                       |  0.000572575 |
# |  639 | sentbyaddress7ema                              |  0.000572607 |
# |  640 | mexican_exchange_high                          |  0.000575279 |
# |  641 | us_10_year_yield                               |  0.000575959 |
# |  642 | marketcap30trx                                 |  0.000576477 |
# |  643 | cocoa_futures_low                              |  0.000576729 |
# |  644 | sentinusd3sma                                  |  0.000577542 |
# |  645 | mining_profitability3wma                       |  0.000577579 |
# |  646 | transactionvalue7ema                           |  0.000578745 |
# |  647 | tweets90var                                    |  0.000579482 |
# |  648 | marketcap90var                                 |  0.000581136 |
# ...
# | 1232 | transactionfees30roc                           |  0.00118876  |
# | 1233 | tweets14ema                                    |  0.00118918  |
# | 1234 | activeaddresses14mom                           |  0.0011921   |
# | 1235 | wheat_futures_volume                           |  0.00119983  |
# | 1236 | size14trx                                      |  0.00120181  |
# | 1237 | fee_to_reward3rsi                              |  0.0012019   |
# | 1238 | transactionvalue3trx                           |  0.00120458  |
# | 1239 | confirmationtime90rsi                          |  0.00120487  |
# | 1240 | transactionfees90mom                           |  0.00120796  |
# | 1241 | activeaddresses14var                           |  0.00121475  |
# | 1242 | fee_to_reward3roc                              |  0.00121733  |
# | 1243 | transactions30std                              |  0.00121747  |
# | 1244 | difficulty14var                                |  0.00121779  |
# | 1245 | german_dax_high                                |  0.0012203   |
# | 1246 | mediantransactionvalue30roc                    |  0.00122296  |
# | 1247 | copper_futures_volume                          |  0.0012233   |
# | 1248 | transactionvalue90roc                          |  0.00122544  |
# | 1249 | transactionvalue3mom                           |  0.00122657  |
# | 1250 | fee_to_reward14trx                             |  0.0012267   |
# | 1251 | tweets30mom                                    |  0.00122729  |
# | 1252 | marketcap7trx                                  |  0.00122849  |
# | 1253 | transactionvalue3var                           |  0.00122856  |
# | 1254 | rough_rice_futures_volume                      |  0.00123118  |
# | 1255 | difficulty3trx                                 |  0.0012313   |
# | 1256 | transactionvalue7trx                           |  0.0012349   |
# | 1257 | fee_to_reward14rsi                             |  0.00123534  |
# | 1258 | activeaddresses7rsi                            |  0.00123565  |
# | 1259 | tweets30ema                                    |  0.00124025  |
# | 1260 | mediantransactionvalue90mom                    |  0.0012404   |
# | 1261 | sentinusd14mom                                 |  0.00124572  |
# | 1262 | top100cap90rsi                                 |  0.00125223  |
# | 1263 | sentbyaddress14trx                             |  0.00125272  |
# | 1264 | mediantransactionvalue7rsi                     |  0.00125509  |
# | 1265 | activeaddresses7trx                            |  0.00125563  |
# | 1266 | google_trends7roc                              |  0.00125567  |
# | 1267 | median_transaction_fee30roc                    |  0.00125677  |
# | 1268 | mining_profitability30rsi                      |  0.00126087  |
# | 1269 | tweets3mom                                     |  0.00126094  |
# | 1270 | lumber_futures_volume                          |  0.00126566  |
# | 1271 | sentinusd14var                                 |  0.00126762  |
# | 1272 | activeaddresses3var                            |  0.00126827  |
# | 1273 | coffee_futures_low                             |  0.00126901  |
# | 1274 | top100cap3trx                                  |  0.00127236  |
# | 1275 | top100cap3std                                  |  0.00127277  |
# | 1276 | transactions3mom                               |  0.00127417  |
# | 1277 | fee_to_reward30rsi                             |  0.00127469  |
# | 1278 | mediantransactionvalue90rsi                    |  0.00127637  |
# | 1279 | mining_profitability14trx                      |  0.00127657  |
# | 1280 | size90mom                                      |  0.00127719  |
# | 1281 | transactions30mom                              |  0.00127875  |
# | 1282 | hashrate90mom                                  |  0.00128064  |
# | 1283 | sentbyaddress3rsi                              |  0.00128396  |
# | 1284 | google_trends7rsi                              |  0.00128614  |
# | 1285 | google_trends7mom                              |  0.00128822  |
# | 1286 | confirmationtime30roc                          |  0.00128831  |
# | 1287 | top100cap30rsi                                 |  0.00129145  |
# | 1288 | confirmationtime30sma                          |  0.00129196  |
# | 1289 | confirmationtime3roc                           |  0.00129281  |
# | 1290 | median_transaction_fee3trx                     |  0.00129672  |
# | 1291 | fee_to_reward90roc                             |  0.0012998   |
# | 1292 | lean_hogs_futures_close                        |  0.00130068  |
# | 1293 | transactions7var                               |  0.00130343  |
# | 1294 | price7trx                                      |  0.00130425  |
# | 1295 | size14mom                                      |  0.00130457  |
# | 1296 | mining_profitability14mom                      |  0.00130481  |
# | 1297 | google_trends14roc                             |  0.00130534  |
# | 1298 | transactions30roc                              |  0.00130567  |
# | 1299 | mediantransactionvalue3std                     |  0.00130597  |
# | 1300 | price3trx                                      |  0.00130823  |
# | 1301 | fee_to_reward14roc                             |  0.00131006  |
# | 1302 | transactionvalue7var                           |  0.00131018  |
# | 1303 | sentinusd7mom                                  |  0.00131154  |
# | 1304 | confirmationtime14var                          |  0.00131555  |
# | 1305 | google_trends7trx                              |  0.00131787  |
# | 1306 | transactions3trx                               |  0.00131887  |
# | 1307 | sentbyaddress3mom                              |  0.00132247  |
# | 1308 | transactionvalue7mom                           |  0.00132494  |
# | 1309 | euro_stoxx_50_volume                           |  0.00132537  |
# | 1310 | price14rsi                                     |  0.00132724  |
# | 1311 | hashrate3roc                                   |  0.00132867  |
# | 1312 | transactions90rsi                              |  0.00132892  |
# | 1313 | hashrate30mom                                  |  0.00132952  |
# | 1314 | size14rsi                                      |  0.00133072  |
# | 1315 | tweets90mom                                    |  0.00133154  |
# | 1316 | french_cac_40_volume                           |  0.0013316   |
# | 1317 | size30trx                                      |  0.0013397   |
# | 1318 | google_trends14mom                             |  0.00134086  |
# | 1319 | tweets14rsi                                    |  0.00134466  |
# | 1320 | difficulty3var                                 |  0.00135778  |
# | 1321 | hashrate7mom                                   |  0.00136103  |
# | 1322 | mediantransactionvalue3mom                     |  0.00136698  |
# | 1323 | sentinusd3roc                                  |  0.00137068  |
# | 1324 | tweets14mom                                    |  0.00137128  |
# | 1325 | sentinusd30rsi                                 |  0.00137698  |
# | 1326 | marketcap7roc                                  |  0.00137836  |
# | 1327 | sentinusd30roc                                 |  0.00138914  |
# | 1328 | fee_to_reward14mom                             |  0.00139198  |
# | 1329 | google_trends90roc                             |  0.00139487  |
# | 1330 | size7rsi                                       |  0.00139487  |
# | 1331 | median_transaction_fee14roc                    |  0.00139798  |
# | 1332 | confirmationtime14sma                          |  0.00139831  |
# | 1333 | coffee_futures_close                           |  0.00140022  |
# | 1334 | mining_profitability90rsi                      |  0.00140138  |
# | 1335 | confirmationtime3sma                           |  0.00140241  |
# | 1336 | confirmationtime14roc                          |  0.00140595  |
# | 1337 | mining_profitability3trx                       |  0.00140695  |
# | 1338 | sentbyaddress7rsi                              |  0.00140977  |
# | 1339 | transactionvalue14roc                          |  0.00141041  |
# | 1340 | size90rsi                                      |  0.00141123  |
# | 1341 | size7std                                       |  0.00141463  |
# | 1342 | hashrate7rsi                                   |  0.00141819  |
# | 1343 | transactionvalue30mom                          |  0.00141858  |
# | 1344 | rank_bit_x                                     |  0.00141984  |
# | 1345 | confirmationtime30rsi                          |  0.00142131  |
# | 1346 | mediantransactionvalue14mom                    |  0.00142275  |
# | 1347 | hashrate14roc                                  |  0.00143043  |
# | 1348 | transactions7roc                               |  0.0014308   |
# | 1349 | activeaddresses3mom                            |  0.00143106  |
# | 1350 | transactions7mom                               |  0.00143294  |
# | 1351 | activeaddresses14roc                           |  0.00143521  |
# | 1352 | confirmationtime3rsi                           |  0.00143625  |
# | 1353 | hashrate30roc                                  |  0.00143803  |
# | 1354 | sentinusd7roc                                  |  0.00144643  |
# | 1355 | sentinusd30mom                                 |  0.00145191  |
# | 1356 | sentinusd3rsi                                  |  0.00145506  |
# | 1357 | sentbyaddress7roc                              |  0.00146119  |
# | 1358 | hashrate14mom                                  |  0.00146224  |
# | 1359 | size30rsi                                      |  0.00146528  |
# | 1360 | size14roc                                      |  0.00147735  |
# | 1361 | activeaddresses7var                            |  0.00147784  |
# | 1362 | activeaddresses7roc                            |  0.00147795  |
# | 1363 | marketcap3mom                                  |  0.00148296  |
# | 1364 | marketcap14mom                                 |  0.00148388  |
# | 1365 | tweets3trx                                     |  0.00150865  |
# | 1366 | activeaddresses90mom                           |  0.00150951  |
# | 1367 | mining_profitability7roc                       |  0.00151091  |
# | 1368 | rank_coinbase                                  |  0.00151737  |
# | 1369 | sentbyaddress3std                              |  0.00152603  |
# | 1370 | sentinusd14rsi                                 |  0.00153256  |
# | 1371 | mediantransactionvalue14roc                    |  0.00153361  |
# | 1372 | top100cap7roc                                  |  0.00153384  |
# | 1373 | transactionfees3roc                            |  0.00153827  |
# | 1374 | mexican_exchange_volume                        |  0.00154431  |
# | 1375 | sentinusd7rsi                                  |  0.00154932  |
# | 1376 | size3trx                                       |  0.00155069  |
# | 1377 | size3std                                       |  0.00155396  |
# | 1378 | confirmationtime30mom                          |  0.00155686  |
# | 1379 | google_trends3rsi                              |  0.00156666  |
# | 1380 | confirmationtime90roc                          |  0.00157472  |
# | 1381 | price3mom                                      |  0.00157956  |
# | 1382 | tweets14roc                                    |  0.00158083  |
# | 1383 | price7mom                                      |  0.00158531  |
# | 1384 | transactionfees3mom                            |  0.00159931  |
# | 1385 | activeaddresses3roc                            |  0.00160303  |
# | 1386 | tweets7roc                                     |  0.0016064   |
# | 1387 | trades_per_minute                              |  0.00160923  |
# | 1388 | mining_profitability7rsi                       |  0.0016113   |
# | 1389 | size90roc                                      |  0.00161194  |
# | 1390 | confirmationtime14rsi                          |  0.00162004  |
# | 1391 | top100cap7std                                  |  0.00162639  |
# | 1392 | transactionvalue7roc                           |  0.00162712  |
# | 1393 | median_transaction_fee3rsi                     |  0.00163183  |
# | 1394 | price3roc                                      |  0.00163254  |
# | 1395 | size3rsi                                       |  0.00163283  |
# | 1396 | tweets14trx                                    |  0.0016419   |
# | 1397 | mediantransactionvalue3roc                     |  0.00165018  |
# | 1398 | sentbyaddress3var                              |  0.00165053  |
# | 1399 | tweets30roc                                    |  0.00165263  |
# | 1400 | hashrate3trx                                   |  0.00165783  |
# | 1401 | tweets7rsi                                     |  0.00167627  |
# | 1402 | confirmationtime7roc                           |  0.00167798  |
# | 1403 | hashrate3rsi                                   |  0.00168005  |
# | 1404 | activeaddresses7mom                            |  0.00168396  |
# | 1405 | transactionvalue30rsi                          |  0.00168999  |
# | 1406 | size7roc                                       |  0.00169287  |
# | 1407 | top100cap3mom                                  |  0.00169333  |
# | 1408 | mediantransactionvalue3var                     |  0.00170106  |
# | 1409 | mining_profitability3rsi                       |  0.00170459  |
# | 1410 | tweets3roc                                     |  0.00170676  |
# | 1411 | difficulty3mom                                 |  0.00171388  |
# | 1412 | time_between_blocks                            |  0.00172936  |
# | 1413 | confirmationtime14mom                          |  0.0017318   |
# | 1414 | transactionfees3rsi                            |  0.00174229  |
# | 1415 | marketcap3rsi                                  |  0.00174522  |
# | 1416 | size30mom                                      |  0.00174557  |
# | 1417 | transactionvalue7rsi                           |  0.00174561  |
# | 1418 | marketcap14rsi                                 |  0.00175021  |
# | 1419 | hashrate3mom                                   |  0.0017612   |
# | 1420 | mediantransactionvalue3trx                     |  0.00176562  |
# | 1421 | google_trends3trx                              |  0.00176593  |
# | 1422 | transactions3var                               |  0.00176761  |
# | 1423 | transactionvalue3rsi                           |  0.0017763   |
# | 1424 | confirmationtime3var                           |  0.00178448  |
# | 1425 | fee_to_reward3trx                              |  0.00179624  |
# | 1426 | confirmationtime3mom                           |  0.00180177  |
# | 1427 | activeaddresses30rsi                           |  0.00180349  |
# | 1428 | hashrate14rsi                                  |  0.00180393  |
# | 1429 | size3roc                                       |  0.00181175  |
# | 1430 | google_trends3std                              |  0.00181253  |
# | 1431 | mining_profitability3roc                       |  0.00182902  |
# | 1432 | confirmationtime7mom                           |  0.00186068  |
# | 1433 | tweets7mom                                     |  0.00188054  |
# | 1434 | price7roc                                      |  0.00189971  |
# | 1435 | fee_to_reward3std                              |  0.00191645  |
# | 1436 | transactionvalue3roc                           |  0.0019175   |
# | 1437 | activeaddresses90roc                           |  0.00193402  |
# | 1438 | marketcap7rsi                                  |  0.00197475  |
# | 1439 | size7mom                                       |  0.00197521  |
# | 1440 | sentinusd14roc                                 |  0.00199096  |
# | 1441 | tweets3rsi                                     |  0.00200841  |
# | 1442 | mining_profitability14roc                      |  0.00201727  |
# | 1443 | fee_to_reward7roc                              |  0.00204221  |
# | 1444 | confirmationtime30var                          |  0.00204265  |
# | 1445 | price7rsi                                      |  0.00212474  |
# | 1446 | price3rsi                                      |  0.00218553  |
# | 1447 | size3mom                                       |  0.0022268   |
# | 1448 | mediantransactionvalue7roc                     |  0.00227829  |
# | 1449 | tweets90roc                                    |  0.00234711  |
# | 1450 | hashrate7roc                                   |  0.0037879   |

# %% [markdown]
# !! 1449 - tweets90roc
# !! 1441 - tweets3rsi
# ^^ 1438 - marketcap7rsi
# !! 1433 - tweets7mom
# -- 1430 - google_trends3std
# -- 1421 - google_trends3trx
# ^^ 1418 - marketcap14rsi
# ^^ 1415 - marketcap3rsi
# !! 1410 - tweets3roc
# !! 1401 - tweets7rsi
# !! 1399 - tweets30roc
# !! 1396 - tweets14trx
# !! 1386 - tweets7roc
# !! 1382 - tweets14roc
# -- 1379 - google_trends3rsi
# ^^ 1368 - rank_coinbase
# !! 1365 - tweets3trx
# ^^ 1364 - marketcap14mom
# ^^ 1363 - marketcap3mom
# ^^ 1344 - rank_bit_x
# ++ 1333 - coffee_futures_close
# -- 1329 - google_trends90roc
# ^^ 1326 - marketcap7roc
# !! 1324 - tweets14mom
# !! 1319 - tweets14rsi
# -- 1318 - google_trends14mom
# ** 1316 - french_cac_40_volume
# !! 1315 - tweets90mom
# ** 1309 - euro_stoxx_50_volume
# -- 1305 - google_trends7trx
# -- 1297 - google_trends14roc
# ++ 1292 - lean_hogs_futures_close
# -- 1284 - google_trends7rsi
# -- 1285 - google_trends7mom
# ++ 1273 - coffee_futures_low
# ++ 1270 - lumber_futures_volume
# !! 1269 - tweets3mom
# -- 1266 - google_trends7roc
# ++ 1254 - rough_rice_futures_volume
# ^^ 1252 - marketcap7trx
# !! 1251 - tweets30mom

# %% [markdown]
# My features = 20.5 % of Top 200
# -------
#  - 1%   = stock indices
#  - 2.5% = commidity futures
#  - 4.5% = other internal features I added
#  - 5%   = features on google trend of "bitcoin"
#  - 7.5% = features on tweets containing "bitcoin"
